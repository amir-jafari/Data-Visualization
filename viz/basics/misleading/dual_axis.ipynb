# %% [markdown]
# # Two y axes
#
# **Two y axes -- where correlation is manufactured.**
#
# Put two series on two different y axes and you get to choose the scales. Any two lines can be made to cross, touch, or move together. The reader sees a relationship that you invented with a scaling factor.
#
# **What it shows:**
#
# - one pair of series made to tell three different stories
# - why the crossing point is meaningless
# - three honest alternatives that keep the information
#
# ---
#
# *Chapter:* `misleading` — how charts lie — so you can stop doing it by accident
# *Run the cells in order.* Every figure is also written to `viz/output/misleading/`, which is what the Streamlit gallery (`viz/project/gallery.py`) reads.

# %% [markdown]
# ## Setup
#
# These lines are how every notebook in the folder finds `vizkit.py`, which holds the save helpers and the seeded sample data. The data is seeded on purpose: your figures should come out identical to everyone else's.
#
# `save()` writes each figure into `viz/output/` **and** leaves it on screen here. The trailing `;` on those calls only stops the notebook echoing the path it returns.

# %%
# %matplotlib inline

# A notebook has no __file__, so find viz/ by walking up from this
# notebook's own folder until vizkit.py turns up.
import sys
from pathlib import Path

VIZ = next(p for p in [Path.cwd(), *Path.cwd().parents]
           if (p / "vizkit.py").exists())
sys.path.insert(0, str(VIZ))

import matplotlib.pyplot as plt
import numpy as np

from vizkit import save, two_series

# Where save() files this lesson's output: viz/output/misleading/
LESSON = "misleading/dual_axis"

# %% [markdown]
# ## The data
#
# Revenue in thousands and headcount in people — two real quantities on wildly different scales, which is the situation that tempts people into a second y axis.

# %%
data = two_series()
months, revenue, headcount = data["month"], data["revenue_k"], data["headcount"]

# %% [markdown]
# ## 1. The same data, three "findings"
#
# Three panels, one dataset, three contradictory findings. The only thing that changed is the pair of `set_ylim` calls. Where the two lines cross is a property of your scale choices, not of the data.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

scalings = [
    ((150, 450), (10, 30), "'headcount tracks revenue'"),
    ((150, 450), (0, 60), "'revenue outgrew the team'"),
    ((0, 900), (10, 26), "'the team outgrew revenue'"),
]

for ax, (rev_lim, head_lim, story) in zip(axes, scalings):
    ax.plot(months, revenue, color="#0072B2", lw=2)
    ax.set_ylim(*rev_lim)
    ax.set_ylabel("revenue ($k)", color="#0072B2")
    ax.tick_params(axis="y", labelcolor="#0072B2")
    ax.tick_params(axis="x", rotation=30, labelsize=7)

    twin = ax.twinx()
    twin.plot(months, headcount, color="#D55E00", lw=2)
    twin.set_ylim(*head_lim)
    twin.set_ylabel("headcount", color="#D55E00")
    twin.tick_params(axis="y", labelcolor="#D55E00")

    ax.set_title(story, fontsize=11)

fig.suptitle("Identical data in all three. Only the two y ranges changed.",
             fontsize=12)
fig.tight_layout()
save(fig, LESSON, "three-stories");

# %% [markdown]
# ## 2. The honest alternatives
#
# Three ways out, in increasing order of commitment. Separate panels imply nothing. Indexing to 100 puts both on one honest axis and compares growth. Plotting the ratio says what you actually meant.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# (a) Two panels, stacked. Nothing is hidden and nothing is implied.
axes[0].plot(months, revenue, color="#0072B2", lw=2)
axes[0].set_title("a) separate panels", fontsize=10)
axes[0].set_ylabel("revenue ($k)")
axes[0].tick_params(axis="x", rotation=30, labelsize=7)

# (b) Index both to their starting value: now they share one honest axis.
axes[1].plot(months, 100 * revenue / revenue.iloc[0], color="#0072B2",
             lw=2, label="revenue")
axes[1].plot(months, 100 * headcount / headcount.iloc[0], color="#D55E00",
             lw=2, label="headcount")
axes[1].axhline(100, color="#999999", lw=0.8)
axes[1].set_title("b) indexed to 100 at the start", fontsize=10)
axes[1].set_ylabel("index (first month = 100)")
axes[1].legend(fontsize=8)
axes[1].tick_params(axis="x", rotation=30, labelsize=7)

# (c) Plot the thing you actually mean: the ratio.
axes[2].plot(months, revenue / headcount, color="#009E73", lw=2)
axes[2].set_title("c) the ratio -- revenue per head", fontsize=10)
axes[2].set_ylabel("$k per person")
axes[2].tick_params(axis="x", rotation=30, labelsize=7)

fig.suptitle("Three honest ways to compare two series on different scales",
             fontsize=12)
fig.tight_layout()
save(fig, LESSON, "alternatives")

correlation = np.corrcoef(revenue, headcount)[0, 1]
print(f"""
  The real relationship, unchanged by any of the pictures above:
    correlation(revenue, headcount) = {correlation:.2f}

  A dual axis lets you pick where the lines cross. That crossing point means
  nothing -- it is a property of your two scale choices, not the data.

  Instead: separate panels, index both to 100, or plot the ratio.
""")

# %% [markdown]
# ## Try it yourself
#
# Edit the cells above and re-run them — that is what the notebook is for.
#
# 1. Find `set_ylim` pairs that make the two lines cross in month 6, and another pair that makes them never cross. How long did that take?
# 2. Add a fourth honest option: a scatter of revenue against headcount, coloured by month. What does it show that the others do not?
# 3. The printed correlation is unchanged by every picture above. When is a dual axis defensible anyway — can you name a real case?

# %%
# your turn

# %% [markdown]
# ---
#
# **Previous:** [`misleading/truncated_axis`](truncated_axis.ipynb)
# **Next:** [`misleading/area_vs_radius`](area_vs_radius.ipynb)
