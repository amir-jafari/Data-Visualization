# %% [markdown]
# # Titles that say the finding
#
# **The title should say the finding, not name the axes.**
#
# "Sales by region, 2024-2025" tells the reader what they are looking at. They could see that. "West overtook East in March" tells them what to conclude -- which is the reason you drew the chart.
#
# **What it shows:**
#
# - descriptive versus declarative titles, side by side
# - a subtitle carrying the detail so the title can carry the point
# - a source note, which is what makes a chart quotable
# - removing chart junk so the message has room
#
# ---
#
# *Chapter:* `annotation` — labels, highlighting, and titles that say something
# *Run the cells in order.* Every figure is also written to `viz/output/annotation/`, which is what the Streamlit gallery (`viz/project/gallery.py`) reads.

# %% [markdown]
# ## Setup
#
# These lines are how every notebook in the folder finds `vizkit.py`, which holds the save helpers and the seeded sample data. The data is seeded on purpose: your figures should come out identical to everyone else's.
#
# `save()` writes each figure into `viz/output/` **and** leaves it on screen here. The trailing `;` on those calls only stops the notebook echoing the path it returns.

# %%
# %matplotlib inline

# A notebook has no __file__, so find viz/ by walking up from this
# notebook's own folder until vizkit.py turns up.
import sys
from pathlib import Path

VIZ = next(p for p in [Path.cwd(), *Path.cwd().parents]
           if (p / "vizkit.py").exists())
sys.path.insert(0, str(VIZ))

import matplotlib.pyplot as plt

from vizkit import save, sales

# Where save() files this lesson's output: viz/output/annotation/
LESSON = "annotation/titles"

# %% [markdown]
# ## The data, and the finding
#
# The crossover month is computed from the data rather than typed in — so if the numbers change, the title changes with them instead of quietly going stale.

# %%
wide = sales().pivot(index="month", columns="region", values="sales")
crossover = None
for month in wide.index:
    if wide.loc[month, "West"] > wide.loc[month, "East"]:
        crossover = month
        break

# %% [markdown]
# ## 1. Descriptive vs declarative
#
# 'Sales by region, 2024-2025' tells the reader what they are looking at, which they can already see. 'West overtook East in March' tells them what to conclude, which is why you drew it. The detail moves down into a subtitle.

# %%
fig, (left, right) = plt.subplots(1, 2, figsize=(13, 4.5))

for ax in (left, right):
    for region in wide.columns:
        ax.plot(wide.index, wide[region], color="#D9D9D9", lw=1.5)
    ax.plot(wide.index, wide["West"], color="#0072B2", lw=2.5)
    ax.plot(wide.index, wide["East"], color="#D55E00", lw=2.5)
    ax.tick_params(axis="x", rotation=30, labelsize=8)

left.set_title("Sales by region, 2024-2025")
left.legend(["North", "South", "East", "West"], fontsize=7)

# Declarative: the title states the conclusion, a subtitle holds the detail.
right.set_title(f"West overtook East in {crossover:%B %Y}",
                fontsize=13, fontweight="bold", loc="left")
right.text(0.0, 1.02, "Monthly sales by region, all four regions shown",
           transform=right.transAxes, fontsize=9, color="#666666")
right.annotate("West", xy=(wide.index[-1], wide["West"].iloc[-1]),
               xytext=(6, 0), textcoords="offset points",
               color="#0072B2", fontweight="bold", va="center")
right.annotate("East", xy=(wide.index[-1], wide["East"].iloc[-1]),
               xytext=(6, 0), textcoords="offset points",
               color="#D55E00", fontweight="bold", va="center")
right.set_xlim(wide.index[0], wide.index[-1] + (wide.index[-1] - wide.index[-4]))

fig.tight_layout()
save(fig, LESSON, "descriptive-vs-declarative");

# %% [markdown]
# ## 2. The finished article
#
# Everything from the chapter at once: declarative title, subtitle carrying the detail, direct labels, the crossover marked, the junk removed, and a source note — which is the line that makes a chart quotable.

# %%
fig, ax = plt.subplots(figsize=(9, 5))

for region in wide.columns:
    ax.plot(wide.index, wide[region], color="#D9D9D9", lw=1.5)
ax.plot(wide.index, wide["West"], color="#0072B2", lw=2.8)
ax.plot(wide.index, wide["East"], color="#D55E00", lw=2.8)

ax.axvline(crossover, color="#999999", lw=1, linestyle="--", zorder=0)
ax.annotate("crossover", xy=(crossover, wide.to_numpy().min()),
            xytext=(6, 4), textcoords="offset points",
            fontsize=8, color="#666666")

for region, colour in [("West", "#0072B2"), ("East", "#D55E00")]:
    ax.annotate(region, xy=(wide.index[-1], wide[region].iloc[-1]),
                xytext=(6, 0), textcoords="offset points",
                color=colour, fontweight="bold", va="center")

# Chart junk removal: no top/right frame, faint horizontal guides only.
for side in ("top", "right"):
    ax.spines[side].set_visible(False)
ax.grid(axis="y", alpha=0.3)
ax.set_axisbelow(True)

ax.set_title(f"West overtook East in {crossover:%B %Y}",
             fontsize=15, fontweight="bold", loc="left", pad=26)
ax.text(0.0, 1.04, "Monthly sales by region. Other regions shown in grey.",
        transform=ax.transAxes, fontsize=10, color="#666666")
ax.set_ylabel("sales ($k)")
ax.set_xlim(wide.index[0], wide.index[-1] + (wide.index[-1] - wide.index[-4]))
fig.text(0.01, -0.02, "Source: vizkit.sales() — synthetic course data",
         fontsize=8, color="#999999")

fig.tight_layout()
save(fig, LESSON, "finished");

# %% [markdown]
# ## Rules of thumb
#
# ```text
# Title  = the finding      ("West overtook East in March")
# Subtitle = the detail     ("Monthly sales by region")
# Source note = credibility (where the numbers came from)
# ```

# %% [markdown]
# ## Try it yourself
#
# Edit the cells above and re-run them — that is what the notebook is for.
#
# 1. Write three different true declarative titles for section 2's chart. Which one would you defend in a meeting?
# 2. Delete the source note and the subtitle. What can a reader no longer check?
# 3. Change `sales()` to `sales(seed=7)` in the setup cell. Does the computed title still hold, and would a hard-coded one have?

# %%
# your turn

# %% [markdown]
# ---
#
# **Previous:** [`annotation/highlight`](highlight.ipynb)
# **Next:** [`layout/small_multiples`](../layout/small_multiples.ipynb)
