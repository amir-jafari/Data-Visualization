# %% [markdown]
# # Comparing categories
#
# **Comparing categories -- bars, and what to use when bars stop working.**
#
# > **The question this chart answers:** "which is biggest?"
#
# **What it shows:**
#
# - bars must start at zero, because you read them by LENGTH
# - sort by value, not alphabetically -- ordering is free information
# - horizontal bars when the labels are words
# - a dot plot when there are many categories or a narrow range
#
# The rule underneath: match the mark to the comparison. Length works for "how much"; position works for "where in the range".
#
# ---
#
# *Chapter:* `choosing` — which chart answers which question
# *Run the cells in order.* Every figure is also written to `viz/output/choosing/`, which is what the Streamlit gallery (`viz/project/gallery.py`) reads.

# %% [markdown]
# ## Setup
#
# These lines are how every notebook in the folder finds `vizkit.py`, which holds the save helpers and the seeded sample data. The data is seeded on purpose: your figures should come out identical to everyone else's.
#
# `save()` writes each figure into `viz/output/` **and** leaves it on screen here. The trailing `;` on those calls only stops the notebook echoing the path it returns.

# %%
# %matplotlib inline

# A notebook has no __file__, so find viz/ by walking up from this
# notebook's own folder until vizkit.py turns up.
import sys
from pathlib import Path

VIZ = next(p for p in [Path.cwd(), *Path.cwd().parents]
           if (p / "vizkit.py").exists())
sys.path.insert(0, str(VIZ))

import matplotlib.pyplot as plt

from vizkit import save, survey

# Where save() files this lesson's output: viz/output/choosing/
LESSON = "choosing/comparison"

# %% [markdown]
# ## The data
#
# `survey()` is six tools and how many people use each — a plain category/count table, which is the shape almost every comparison chart starts from.

# %%
data = survey()

# %% [markdown]
# ## 1. The default, and what is wrong with it
#
# Two charts, same six numbers. Read the left one and try to rank Excel against SQL; then read the right one. The difference is not prettiness — sorting turned a lookup task into a glance.

# %%
fig, (left, right) = plt.subplots(1, 2, figsize=(11, 4))

# Alphabetical order, vertical bars, rotated labels: three small problems.
alphabetical = data.sort_values("tool")
left.bar(alphabetical["tool"], alphabetical["users"])
left.set_title("Default: alphabetical, labels fighting for room")
left.tick_params(axis="x", rotation=45)

# Sorted, horizontal, labels readable. Same data, much less work for the eye.
ordered = data.sort_values("users")
right.barh(ordered["tool"], ordered["users"], color="#4C72B0")
right.set_title("Sorted and horizontal: the ranking is now obvious")
right.set_xlabel("users")

fig.tight_layout()
save(fig, LESSON, "bars");

# %% [markdown]
# ## 2. Why bars must start at zero
#
# This is the only rule in the chapter with no exceptions. A bar's **length** is the number, so a chopped axis is a chopped number. The right-hand panel is a real chart you will see published; it is the same distortion `misleading/truncated_axis` measures.

# %%
fig, (left, right) = plt.subplots(1, 2, figsize=(11, 4))

left.barh(ordered["tool"], ordered["users"], color="#C44E52")
left.set_xlim(0, 450)
left.set_title("Honest: axis starts at zero")

right.barh(ordered["tool"], ordered["users"], color="#C44E52")
right.set_xlim(300, 430)          # chops the bars off at the bottom
right.set_title("Misleading: axis starts at 300")

fig.suptitle("A bar's LENGTH is the value. Cut the axis and you cut the value.",
             fontsize=11)
fig.tight_layout()
save(fig, LESSON, "zero-baseline");

# %% [markdown]
# ## 3. When a dot plot beats a bar
#
# Once the values are all close together, bars spend most of the picture on the part nobody is arguing about. A dot is read by **position**, so it may start wherever the interesting range does.

# %%
# Bars need the zero, so a narrow range wastes most of the picture. A dot is
# read by POSITION, not length, so it can start wherever it likes.
narrow = data[data["users"] > 100].sort_values("users")

fig, (left, right) = plt.subplots(1, 2, figsize=(11, 3.5))

left.barh(narrow["tool"], narrow["users"], color="#4C72B0")
left.set_title("Bars: honest, but the differences are squashed")

right.hlines(y=narrow["tool"], xmin=narrow["users"].min() - 20,
             xmax=narrow["users"], color="#CCCCCC", lw=1)
right.plot(narrow["users"], narrow["tool"], "o", color="#4C72B0", markersize=9)
right.set_xlim(narrow["users"].min() - 20, narrow["users"].max() + 20)
right.set_title("Dots: read by position, so no zero needed")

fig.tight_layout()
save(fig, LESSON, "dot-plot");

# %% [markdown]
# ## Rules of thumb
#
# ```text
# Choose by the question:
#   "which is biggest?"        -> sorted horizontal bars, starting at zero
#   "how do these few differ?" -> dot plot, zoomed to the interesting range
# ```

# %% [markdown]
# ## Try it yourself
#
# Edit the cells above and re-run them — that is what the notebook is for.
#
# 1. Change `data.sort_values("users")` to `sort_values("users", ascending=False)` in section 1. Which end does the biggest bar end up at, and which reads better for a top-to-bottom ranking?
# 2. In section 2, set the right-hand `set_xlim` to `(340, 420)`. How many times taller does Python now look than SQL, and what is the true ratio?
# 3. Redraw section 3's dot plot with all six tools instead of the four above 100. Does the dot plot still beat bars once Julia and SAS are back in?

# %%
# your turn

# %% [markdown]
# ---
#
# **Next:** [`choosing/distribution`](distribution.ipynb)
